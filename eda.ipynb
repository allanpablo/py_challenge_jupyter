# %% [markdown]
# # 🧪 Análise Exploratória de Dados com Pandas (EDA)
#
# Neste módulo, vamos aprender a **extrair insights** valiosos a partir dos dados utilizando a biblioteca **Pandas**.
#
# A **Análise Exploratória de Dados (EDA)** é uma das etapas mais importantes do processo de análise de dados e ciência de dados. Ela serve para **explorar, entender e preparar** os dados antes de aplicar modelos estatísticos ou algoritmos de Machine Learning.
#
# ## 🎯 Objetivos:
#
# - Compreender o papel do EDA
# - Utilizar `pandas` para manipular e explorar dados
# - Detectar **padrões, anomalias e outliers**
# - Lidar com **dados ausentes** e inconsistências
# - Gerar **gráficos e estatísticas descritivas**
# - Formular hipóteses iniciais com base nos dados
# - Realizar análises **univariadas e bivariadas**
# - Automatizar partes do processo para ganhar produtividade
#
# ## 🧠 Metodologia
#
# A abordagem será prática e direta, com foco em:
# - Investigar o comportamento das variáveis
# - Verificar a qualidade dos dados
# - Descobrir relações e tendências escondidas
# - Preparar os dados para análises futuras
#
# Vamos atuar como **investigadores curiosos**, destrinchando os dados em busca de respostas.
#
# > “Sem EDA, modelar é atirar no escuro.”
#
# ---

# %% [markdown]
# # 📊 Exploratory Data Analysis (EDA) com Pandas
#
# Neste módulo, vamos explorar o conceito de **Análise Exploratória de Dados (Exploratory Data Analysis - EDA)** e como aplicá-la em projetos reais de ciência de dados utilizando a biblioteca **Pandas**.
#
# ## 🔍 O que é EDA?
#
# EDA é um **processo sistemático** que nos permite:
# - Compreender a estrutura e o conteúdo de um conjunto de dados
# - Identificar padrões, tendências, inconsistências e outliers
# - Formular hipóteses para análises mais profundas
#
# ## 🛠️ Etapas principais do EDA:
#
# 1. **Coleta e preparação dos dados**
#    - Capturar dados de diferentes fontes (CSV, banco de dados, APIs, etc.)
#    - Realizar limpeza, transformação e padronização
#    - Tratar valores ausentes e dados atípicos
#
# 2. **Formulação de hipóteses e análise estatística**
#    - Análise **univariada**: comportamento de uma única variável
#    - Análise **bivariada**: relação entre duas variáveis (ex: correlação)
#    - Análise **multivariada**: padrões entre múltiplas variáveis
#    - Análise **temporal**: evolução ao longo do tempo
#
# 3. **Visualização e comunicação de resultados**
#    - Usar gráficos para facilitar a interpretação dos dados
#    - Comunicar insights de forma clara, adaptando-se ao público-alvo
#    - Evitar jargões técnicos quando a audiência não for técnica
#
# ## 🐼 A Biblioteca Pandas
#
# O **Pandas** é uma biblioteca essencial para análise de dados em Python. Ele fornece:
# - Estruturas eficientes como **DataFrame** e **Series**
# - Compatibilidade com arquivos CSV, Excel, SQL, JSON e mais
# - Recursos para:
#   - Filtragem de dados
#   - Limpeza e transformação
#   - Cálculos agregados e estatísticas
#   - Organização e análise por grupos (groupby)
#   - Integração com bibliotecas de visualização como Matplotlib e Seaborn
#
# ## ✅ Conclusão
#
# A EDA é uma etapa **fundamental para todo projeto de dados**.
# Com Pandas, conseguimos transformar dados crus em **informações valiosas** para tomada de decisão, modelagem e comunicação com stakeholders.
#
# ---

# %% [markdown]
# # 📊 Análise Exploratória de Dados (EDA) na Prática – Setor de Telecom
#
# Nesta aula, vamos aplicar os conceitos de **Análise Exploratória de Dados (EDA)** em um cenário real do setor de **Telecomunicações**.
#
# ## 📁 Sobre os Dados
#
# Trabalharemos com **três conjuntos de dados** contendo informações de:
# - Perfil dos clientes
# - Serviços contratados
# - Status de permanência ou abandono (churn)
#
# ## 🎯 Objetivo
#
# O nosso objetivo é:
# - Realizar o tratamento inicial dos dados
# - Gerar insights com base em hipóteses simples
# - Iniciar a construção de uma solução de **inteligência artificial** para prever o **abandono de clientes ativos**
#
# ## 🛠️ O que vamos fazer nesta etapa:
#
# 1. **Coletar e carregar os dados** usando a biblioteca `pandas`
# 2. **Transformar tipos de dados** (por exemplo, datas, numéricos, booleanos)
# 3. **Renomear colunas** para melhorar a legibilidade
# 4. **Unificar os datasets** em um único DataFrame consolidado
# 5. Iniciar a **exploração dos dados com foco em churn**
#
# > Agora, vamos para o código!

# %%
import pandas as pd

churn_customers = pd.read_csv("churn_customers.csv")
churn_contracts = pd.read_csv("churn_contracts.csv")
churn_services = pd.read_csv("churn_services.csv")
def padroniza_colunas(df):
    df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")
    return df

churn_customers = padroniza_colunas(churn_customers)
churn_contracts = padroniza_colunas(churn_contracts)
churn_services = padroniza_colunas(churn_services)
def padroniza_colunas(df):
    df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")
    return df

churn_customers = padroniza_colunas(churn_customers)
churn_contracts = padroniza_colunas(churn_contracts)
churn_services = padroniza_colunas(churn_services)

# Visualizar as primeiras linhas
display(churn_customers.head(10))
display(churn_contracts.head(10))
display(churn_services.head(10))

# Verificar estrutura dos dados
churn_customers.info()
churn_contracts.info()
churn_services.info()
print(churn_customers.isnull().sum())
print(churn_contracts.isnull().sum())
print(churn_services.isnull().sum())
# Out:
#    customerid  gender  seniorcitizen partner dependents
# 0  7590-VHVEG  Female              0     Yes         No
# 1  5575-GNVDE    Male              0      No         No
# 2  3668-QPYBK    Male              0      No         No
# 3  7795-CFOCW    Male              0      No         No
# 4  9237-HQITU  Female              0      No         No
# 5  9305-CDSKC  Female              0      No         No
# 6  1452-KIOVK    Male              0      No        Yes
# 7  6713-OKOMC  Female              0      No         No
# 8  7892-POOKP  Female              0     Yes         No
# 9  6388-TABGU    Male              0      No        Yes
#    customerid  tenure        contract paperlessbilling  \
# 0  7590-VHVEG       1  Month-to-month              Yes
# 1  5575-GNVDE      34        One year               No
# 2  3668-QPYBK       2  Month-to-month              Yes
# 3  7795-CFOCW      45        One year               No
# 4  9237-HQITU       2  Month-to-month              Yes
# ...

# %% [markdown]
# # 🧮 Transformação de Dados com Pandas - Coluna totalcharges
#
# Nesta aula, vamos trabalhar com a coluna `totalcharges` do DataFrame de contratos, que originalmente está em formato de texto (`object`). Nosso objetivo é convertê-la para o tipo numérico (`float64`) de forma segura, lidando com possíveis valores inválidos.
#
# ---

# %%
# Verificando o tipo original
print(churn_contracts["totalcharges"].dtype)

# Primeira abordagem: astype (erro se houver string vazia)
try:
    churn_contracts["totalcharges_astype"] = churn_contracts["totalcharges"].astype(float)
except Exception as e:
    print("Erro com astype:", e)

# Segunda abordagem: to_numeric sem tratamento (também dá erro)
try:
    churn_contracts["totalcharges_numeric"] = pd.to_numeric(churn_contracts["totalcharges"])
except Exception as e:
    print("Erro com to_numeric padrão:", e)

# Terceira abordagem: to_numeric com errors='coerce' (segura)
churn_contracts["totalcharges"] = pd.to_numeric(churn_contracts["totalcharges"], errors="coerce")

# Verificando estrutura final
print(churn_contracts[["totalcharges", "totalcharges_float"]].info())
# Out:
# object
# Erro com astype: could not convert string to float: ' '
# Erro com to_numeric padrão: Unable to parse string " " at position 488
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   totalcharges        7032 non-null   float64
#  1   totalcharges_float  7032 non-null   float64
# dtypes: float64(2)
# memory usage: 110.2 KB
# None

# %% [markdown]
# ### Após a transformação 11 valores estão ausentes

# %%
# Listar os nomes exatos das colunas do churn_contracts
print(churn_contracts.columns.tolist())
# Out:
# ['customerid', 'tenure', 'contract', 'paperlessbilling', 'paymentmethod', 'monthlycharges', 'totalcharges', 'churn', 'totalcharges_float']

# %%
# Filtrar linhas onde a conversão falhou
churn_contracts[churn_contracts['totalcharges'].isna()]


#churn_contracts.loc[churn_contracts['totalcharges'].isna(), 'customerid']
# Out:
# Empty DataFrame
# Columns: [id_cliente, tenure, contract, paperlessbilling, paymentmethod, monthlycharges, totalcharges, churn]
# Index: []

# %% [markdown]
# # ✏️ Renomeando Colunas no Pandas
#
# Nesta aula, vamos aprender a renomear colunas de um DataFrame utilizando o método `rename()` e outras abordagens. Isso é útil para padronizar nomes ou torná-los mais compreensíveis.
#
# ---

# %%
# Exemplo: renomear colunas específicas com dicionário
churn_contracts.rename(columns={"customerid": "id_cliente", "tenure": "meses_contrato"}, inplace=True)

# Visualizar colunas após renomeação
print(churn_contracts.columns.tolist())
# Out:
# ['id_cliente', 'meses_contrato', 'contract', 'paperlessbilling', 'paymentmethod', 'monthlycharges', 'totalcharges', 'churn', 'totalcharges_float']

# %%
churn_contracts.rename(columns={
    "customerid": "id_cliente",
    "tenure": "meses_contrato",
    "contract": "tipo_contrato",
}, inplace=True)

# %%
print(churn_contracts.columns.tolist())
print(len(churn_contracts.columns))  # deve bater com o tamanho da lista que você vai passar
# Out:
# ['id_cliente', 'meses_contrato', 'tipo_contrato', 'paperlessbilling', 'paymentmethod', 'monthlycharges', 'totalcharges', 'churn', 'totalcharges_float']
# 9

# %%
churn_contracts.columns = [
    'id_cliente',
    'genero',
    'parceiro',
    'dependentes',
    'tipo_contrato',
    'tenure',
    'charges_mensal',
    'totalcharges',
    'churn'
]

# %%
print(churn_contracts)
# Out:
#       id_cliente  genero        parceiro dependentes  \
# 0     7590-VHVEG       1  Month-to-month         Yes
# 1     5575-GNVDE      34        One year          No
# 2     3668-QPYBK       2  Month-to-month         Yes
# 3     7795-CFOCW      45        One year          No
# 4     9237-HQITU       2  Month-to-month         Yes
# ...          ...     ...             ...         ...
# 7038  6840-RESVB      24        One year         Yes
# 7039  2234-XADUH      72        One year         Yes
# 7040  4801-JZAZL      11  Month-to-month         Yes
# 7041  8361-LTMKD       4  Month-to-month         Yes
# 7042  3186-AJIEK      66        Two year         Yes
#
#                   tipo_contrato  tenure  charges_mensal totalcharges    churn
# 0              Electronic check   29.85           29.85           No    29.85
# 1                  Mailed check   56.95         1889.50           No  1889.50
# 2                  Mailed check   53.85          108.15          Yes   108.15
# ...

# %% [markdown]
# ## como nao salvei o arquivo, o original ainda esta aqui

# %%
churn_contracts = pd.read_csv("churn_contracts.csv")

# %%
print(churn_contracts)
# Out:
#       customerID  tenure        Contract PaperlessBilling  \
# 0     7590-VHVEG       1  Month-to-month              Yes
# 1     5575-GNVDE      34        One year               No
# 2     3668-QPYBK       2  Month-to-month              Yes
# 3     7795-CFOCW      45        One year               No
# 4     9237-HQITU       2  Month-to-month              Yes
# ...          ...     ...             ...              ...
# 7038  6840-RESVB      24        One year              Yes
# 7039  2234-XADUH      72        One year              Yes
# 7040  4801-JZAZL      11  Month-to-month              Yes
# 7041  8361-LTMKD       4  Month-to-month              Yes
# 7042  3186-AJIEK      66        Two year              Yes
#
#                   PaymentMethod  MonthlyCharges TotalCharges Churn
# 0              Electronic check           29.85        29.85    No
# 1                  Mailed check           56.95       1889.5    No
# ...

# %%
churn_contracts.columns = churn_contracts.columns.str.strip().str.lower().str.replace(" ", "_")

# %%
churn_contracts_original = churn_contracts.copy()

# %% [markdown]
# # ✅ 1. Usar .copy() para preservar o original
# ## Cria uma cópia do DataFrame original antes de modificar.

# %%
# Preserva o original
churn_contracts_backup = churn_contracts.copy()

# Agora pode mexer sem medo
churn_contracts_renomeado = churn_contracts.copy()
churn_contracts_renomeado.rename(columns={
    "customerid": "id_cliente",
    "tenure": "meses_contrato",
    "contract": "tipo_contrato"
}, inplace=True)

# %% [markdown]
# # ✅ 2. Usar .rename() sem inplace
# ## Retorna um novo DataFrame. O original permanece intocado.

# %%
# Sem alterar o original
churn_contratos_novo = churn_contracts.rename(columns={
    "customerid": "id_cliente",
    "tenure": "meses_contrato"
})

# %% [markdown]
# # 🔗 Aula: Unificando DataFrames no Pandas
#
# Nesta aula, vamos aprender a unir diferentes DataFrames com informações complementares, utilizando o método `merge()` da biblioteca `pandas`.
#
# Nosso objetivo é consolidar os dados de clientes, contratos e serviços em um único DataFrame unificado.
#
# ---

# %%
# ✅ 1. Verificando o tamanho dos DataFrames
print("Clientes:", len(churn_customers))
print("Contratos:", len(churn_contracts))
print("Serviços:", len(churn_services))
# Out:
# Clientes: 7043
# Contratos: 7043
# Serviços: 7043

# %%
# ✅ 2. Padronizando o nome da chave de unificação

# Garantir que a chave esteja com o mesmo nome em todos
churn_customers.rename(columns={"customerid": "id_cliente"}, inplace=True)
churn_contracts.rename(columns={"customerid": "id_cliente"}, inplace=True)
churn_services.rename(columns={"customerid": "id_cliente"}, inplace=True)

# %%
# ✅ 3. Unindo os DataFrames com merge()
# Unir clientes + contratos
df_merged = churn_customers.merge(churn_contracts, on="id_cliente", how="left")

# Unir o resultado anterior com serviços
df_merged = df_merged.merge(churn_services, on="id_cliente", how="left")

# %%
# ✅ 4. Lidando com chaves com nomes diferentes (exemplo)
# Se customerid estivesse com nome diferente em algum DF
# df_merged = churn_customers.merge(churn_contracts, left_on="id_cliente", right_on="customer_id")

# %%
# ✅ 5. Removendo colunas duplicadas (se necessário)
# Excluir colunas duplicadas após merge (ex: 'customer_id_y')
df_merged.drop(columns=[col for col in df_merged.columns if col.endswith('_y')], inplace=True)

# %%
# ✅ 6. Conferência final
print("Total de registros unificados:", len(df_merged))
df_merged.head()
# Out:
# Total de registros unificados: 7043
#    id_cliente  gender  seniorcitizen partner dependents  tenure  \
# 0  7590-VHVEG  Female              0     Yes         No       1
# 1  5575-GNVDE    Male              0      No         No      34
# 2  3668-QPYBK    Male              0      No         No       2
# 3  7795-CFOCW    Male              0      No         No      45
# 4  9237-HQITU  Female              0      No         No       2
#
#          contract paperlessbilling              paymentmethod  monthlycharges  \
# 0  Month-to-month              Yes           Electronic check           29.85
# 1        One year               No               Mailed check           56.95
# 2  Month-to-month              Yes               Mailed check           53.85
# 3        One year               No  Bank transfer (automatic)           42.30
# 4  Month-to-month              Yes           Electronic check           70.70
#
# ...

# %% [markdown]
# # ❓ Aula: Lidando com Dados Ausentes em DataFrames
#
# Nesta aula, vamos entender como identificar e tratar dados ausentes (missing values), que podem prejudicar a análise ou o desempenho de modelos de inteligência artificial.
#
# ## 📌 Tipos de dados ausentes
#
# 1. **MCAR (Missing Completely at Random)**: Ausências ocorrem de forma totalmente aleatória.
#    - Ex: erro de coleta em sensores.
# 2. **MAR (Missing at Random)**: A ausência depende de outras variáveis observadas.
#    - Ex: pessoas com menor renda tendem a não responder perguntas sobre patrimônio.
# 3. **NMAR (Not Missing at Random)**: A ausência depende do próprio valor ausente.
#    - Ex: clientes que cancelaram o serviço não informam o motivo.
#
# ---

# %%
# ✅ 1. Detectar dados ausentes
# Verificar a quantidade de nulos por coluna
print(df_merged.isnull().sum())

df_merged.isna().sum()

# Verificar porcentagem de nulos
print(df_merged.isnull().mean().round(3) * 100)
# Out:
# id_cliente          0
# gender              0
# seniorcitizen       0
# partner             0
# dependents          0
# tenure              0
# contract            0
# paperlessbilling    0
# paymentmethod       0
# monthlycharges      0
# totalcharges        0
# churn               0
# phoneservice        0
# multiplelines       0
# internetservice     0
# onlinesecurity      0
# onlinebackup        0
# deviceprotection    0
# techsupport         0
# streamingtv         0
# streamingmovies     0
# dtype: int64

# %%
# ✅ 2. Remover linhas ou colunas com dados ausentes
# Remover linhas com qualquer valor ausente
df_sem_nulos = df_merged.dropna()

# Remover colunas que possuem muitos nulos (exemplo: mais de 50%)
limite = len(df_merged) * 0.5
df_filtrado = df_merged.dropna(axis=1, thresh=limite)

# %%
# ✅ 3. Preencher (imputar) valores ausentes
# Preencher nulos com zero (ex: valores financeiros)
df_merged['totalcharges'] = df_merged['totalcharges'].fillna(0)

# Preencher com média da coluna
#df_merged['mensalidade'] = df_merged['mensalidade'].fillna(df_merged['mensalidade'].mean())
df_merged['monthlycharges'] = df_merged['monthlycharges'].fillna(df_merged['monthlycharges'].mean())

# Preencher com valor mais frequente (moda)
#df_merged['forma_pagamento'] = df_merged['forma_pagamento'].fillna(df_merged['forma_pagamento'].mode()[0])
df_merged['paymentmethod'] = df_merged['paymentmethod'].fillna(df_merged['paymentmethod'].mode()[0])

# %%
# ✅ 4. Verificar novamente
# Verificar se ainda restam valores ausentes
df_merged.isnull().sum()
# Out:
# id_cliente          0
# gender              0
# seniorcitizen       0
# partner             0
# dependents          0
# tenure              0
# contract            0
# paperlessbilling    0
# paymentmethod       0
# monthlycharges      0
# totalcharges        0
# churn               0
# phoneservice        0
# multiplelines       0
# internetservice     0
# onlinesecurity      0
# onlinebackup        0
# deviceprotection    0
# techsupport         0
# streamingtv         0
# streamingmovies     0
# dtype: int64

# %% [markdown]
# # 🧹 Aula: Técnicas para Lidar com Valores Ausentes no Pandas
#
# Nesta aula, exploramos diferentes estratégias para lidar com valores ausentes em DataFrames:
#
# - ❌ Remoção de colunas com valores nulos
# - 🔁 Imputação (preenchimento) de valores ausentes
# - ⚠️ Considerações para variáveis numéricas e categóricas

# %%
# Total de valores ausentes por coluna
print(df_merged.isnull().sum())
# Out:
# id_cliente          0
# gender              0
# seniorcitizen       0
# partner             0
# dependents          0
# tenure              0
# contract            0
# paperlessbilling    0
# paymentmethod       0
# monthlycharges      0
# totalcharges        0
# churn               0
# phoneservice        0
# multiplelines       0
# internetservice     0
# onlinesecurity      0
# onlinebackup        0
# deviceprotection    0
# techsupport         0
# streamingtv         0
# streamingmovies     0
# dtype: int64

# %%
# Remover colunas com pelo menos 1 valor ausente
df_sem_colunas_nulas = df_merged.dropna(axis=1)

# Remover colunas onde todos os valores são ausentes
df_sem_colunas_todas_nulas = df_merged.dropna(axis=1, how='all')

# %%
# Substitui nulos por 0 na coluna totalcharges
df_merged['totalcharges'] = df_merged['totalcharges'].fillna(0)

# %%
# Substituir nulos por média na coluna monthlycharges
df_merged['monthlycharges'] = df_merged['monthlycharges'].fillna(df_merged['monthlycharges'].mean())

# %%
# Substituir nulos por valor mais frequente (moda)
df_merged['paymentmethod'] = df_merged['paymentmethod'].fillna(df_merged['paymentmethod'].mode()[0])

# %%
# Verificar se ainda restam nulos
print(df_merged.isnull().sum())
# Out:
# id_cliente          0
# gender              0
# seniorcitizen       0
# partner             0
# dependents          0
# tenure              0
# contract            0
# paperlessbilling    0
# paymentmethod       0
# monthlycharges      0
# totalcharges        0
# churn               0
# phoneservice        0
# multiplelines       0
# internetservice     0
# onlinesecurity      0
# onlinebackup        0
# deviceprotection    0
# techsupport         0
# streamingtv         0
# streamingmovies     0
# dtype: int64

# %% [markdown]
# # 📊 Aula: Explorando Hipóteses com Visualizações no EDA
#
# Nesta aula, vamos utilizar visualizações para validar ou refutar hipóteses com base em dados reais do churn de uma empresa de telecom.
#
# ## 🎯 Hipóteses a serem testadas:
#
# 1. Faixa etária influencia a taxa de churn
# 2. Tempo de contrato influencia a permanência
# 3. Tipo de contrato está associado à saída de clientes
#
# Vamos testar essas hipóteses visualmente e com métricas simples.

# %%
print(df_merged.columns.tolist())
# Out:
# ['id_cliente', 'gender', 'seniorcitizen', 'partner', 'dependents', 'tenure', 'contract', 'paperlessbilling', 'paymentmethod', 'monthlycharges', 'totalcharges', 'churn', 'phoneservice', 'multiplelines', 'internetservice', 'onlinesecurity', 'onlinebackup', 'deviceprotection', 'techsupport', 'streamingtv', 'streamingmovies']

# %%
# Mapear 0 para 'Adulto' e 1 para 'Idoso'
df_merged['faixa_etaria'] = df_merged['seniorcitizen'].map({0: 'Adulto', 1: 'Idoso'})

# %%
import matplotlib.pyplot as plt

# Plotar proporção de churn por faixa etária
df_plot = df_merged.groupby('faixa_etaria')['churn'].value_counts(normalize=True).unstack()

df_plot.plot(kind='bar', stacked=True, figsize=(8,5))
plt.title('Proporção de Churn por Faixa Etária')
plt.ylabel('Proporção')
plt.xlabel('Faixa Etária')
plt.legend(title='Churn')
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
# ✅ 2. Tempo de contrato vs Churn
# Histograma comparando tempo de contrato por churn
plt.figure(figsize=(8,5))
sns.histplot(data=df_merged, x='tenure', hue='churn', kde=True, bins=30)
plt.title('Distribuição de Tempo de Contrato por Churn')
plt.xlabel('Meses de Contrato')
plt.ylabel('Contagem')
plt.tight_layout()
plt.show()

# %%
# ✅ 3. Tipo de contrato vs Churn
plt.figure(figsize=(8,5))
sns.countplot(data=df_merged, x='contract', hue='churn')
plt.title('Churn por Tipo de Contrato')
plt.xlabel('Tipo de Contrato')
plt.ylabel('Quantidade de Clientes')
plt.legend(title='Churn')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Com base nessas visualizações, podemos validar se há evidências de associação entre as variáveis analisadas e o churn.
#
# ### Evite assumir causalidade prematuramente. Explore os dados, refine as hipóteses, e valide com múltiplas abordagens.
#
# ### Essas visualizações ajudam a formar intuições e direcionam os próximos passos na modelagem de IA.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Analisando a variável 'monthlycharges'
coluna = 'monthlycharges'

# Ver distribuição básica
print(f"Resumo estatístico de '{coluna}':")
print(df_merged[coluna].describe())

# Medidas de posição
media = df_merged[coluna].mean()
mediana = df_merged[coluna].median()
moda = df_merged[coluna].mode()[0]

print(f"\nMédia: {media:.2f}")
print(f"Mediana: {mediana:.2f}")
print(f"Moda: {moda:.2f}")

# Medidas de dispersão
desvio = df_merged[coluna].std()
variancia = df_merged[coluna].var()
cv = (desvio / media) * 100

print(f"\nDesvio Padrão: {desvio:.2f}")
print(f"Variância: {variancia:.2f}")
print(f"Coeficiente de Variação: {cv:.2f}%")

# Visualizações
plt.figure(figsize=(14, 5))

# Histograma
plt.subplot(1, 2, 1)
sns.histplot(df_merged[coluna], bins=30, kde=True, color='skyblue')
plt.title(f'Distribuição de {coluna}')
plt.xlabel(coluna)

# Boxplot
plt.subplot(1, 2, 2)
sns.boxplot(x=df_merged[coluna], color='lightgreen')
plt.title(f'Boxplot de {coluna}')

plt.tight_layout()
plt.show()
# Out:
# Resumo estatístico de 'monthlycharges':
# count    7043.000000
# mean       64.761692
# std        30.090047
# min        18.250000
# 25%        35.500000
# 50%        70.350000
# 75%        89.850000
# max       118.750000
# Name: monthlycharges, dtype: float64
#
# Média: 64.76
# Mediana: 70.35
# Moda: 20.05
#
# Desvio Padrão: 30.09
# Variância: 905.41
# Coeficiente de Variação: 46.46%

# %% [markdown]
# ## Análise Univariada da Variável "MonthlyCharges"
#
# Nesta etapa da análise exploratória, vamos estudar a distribuição da variável `monthlycharges`, que representa o valor mensal cobrado ao cliente. Esta análise inclui:
#
# - Medidas de posição (média, mediana, moda)
# - Medidas de dispersão (desvio padrão, variância, coeficiente de variação)
# - Visualizações gráficas: histograma e boxplot
#
# Essas informações são importantes para entender o comportamento individual da variável antes de avaliar relações com o churn ou outras variáveis.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Supondo que você já tenha o DataFrame df_merged carregado com os dados unificados

# Análise univariada da variável "churn"
print("Contagem absoluta:")
print(df_merged['churn'].value_counts())
print("\nProporção percentual:")
print(df_merged['churn'].value_counts(normalize=True) * 100)

# Gráfico de barras - contagem absoluta
df_merged['churn'].value_counts().plot(kind='bar', color=['green', 'red'])
plt.title("Distribuição de Churn (Contagem Absoluta)")
plt.xlabel("Churn")
plt.ylabel("Número de Clientes")
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# Gráfico de barras - percentual
(df_merged['churn'].value_counts(normalize=True) * 100).plot(kind='bar', color=['green', 'red'])
plt.title("Distribuição de Churn (Percentual)")
plt.xlabel("Churn")
plt.ylabel("Percentual de Clientes")
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# Análise da variável "contract"
print("\nDistribuição do tipo de contrato:")
print(df_merged['contract'].value_counts())

# Gráfico de barras - tipos de contrato
df_merged['contract'].value_counts().plot(kind='bar', color='skyblue')
plt.title("Distribuição dos Tipos de Contrato")
plt.xlabel("Tipo de Contrato")
plt.ylabel("Número de Clientes")
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# Contagem absoluta:
# churn
# No     5174
# Yes    1869
# Name: count, dtype: int64
#
# Proporção percentual:
# churn
# No     73.463013
# Yes    26.536987
# Name: proportion, dtype: float64
# Distribuição do tipo de contrato:
# contract
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: count, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Verificar se a variável existe
if 'tenure' in df_merged.columns:
    # Estatísticas básicas
    media = df_merged['tenure'].mean()
    mediana = df_merged['tenure'].median()
    desvio_padrao = df_merged['tenure'].std()
    coef_var = (desvio_padrao / media) * 100

    print(f"Média: {media:.2f}")
    print(f"Mediana: {mediana}")
    print(f"Desvio Padrão: {desvio_padrao:.2f}")
    print(f"Coeficiente de Variação: {coef_var:.2f}%")

    # Histograma da variável 'tenure'
    plt.figure(figsize=(8,5))
    plt.hist(df_merged['tenure'], bins=20, color='skyblue', edgecolor='black')
    plt.title("Distribuição do Tempo de Contrato (Tenure)")
    plt.xlabel("Meses de Contrato")
    plt.ylabel("Número de Clientes")
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()
else:
    print("A coluna 'tenure' não foi encontrada no DataFrame.")
# Out:
# Média: 32.37
# Mediana: 29.0
# Desvio Padrão: 24.56
# Coeficiente de Variação: 75.87%

# %% [markdown]
# ✅ O que esse código faz:
# Gera média, mediana, desvio padrão e coeficiente de variação da coluna tenure
#
# Plota um histograma mostrando a distribuição do tempo de contrato
#
# Permite visualizar padrões, como concentração de clientes com contratos curtos ou longos

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Verificar se colunas existem
if 'contract' in df_merged.columns and 'churn' in df_merged.columns:

    # Contagem simples
    contagem_contratos = df_merged['contract'].value_counts()
    print("Contagem de tipos de contrato:")
    print(contagem_contratos)

    # Agrupamento por contrato e churn
    agrupado = df_merged.groupby(['contract', 'churn']).size().reset_index(name='contagem')
    print("\nContagem agrupada por contrato e churn:")
    print(agrupado)

    # Ordenar por maior contagem
    agrupado_ordenado = agrupado.sort_values(by='contagem', ascending=False)

    # Gráfico de barras empilhadas
    tabela_pivot = df_merged.pivot_table(index='contract', columns='churn', aggfunc='size', fill_value=0)
    tabela_pivot.plot(kind='bar', stacked=True, figsize=(8,5), colormap='Set2')
    plt.title('Distribuição de Churn por Tipo de Contrato')
    plt.ylabel('Número de Clientes')
    plt.xlabel('Tipo de Contrato')
    plt.xticks(rotation=0)
    plt.legend(title='Churn')
    plt.tight_layout()
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()

else:
    print("Colunas 'contract' ou 'churn' não encontradas no DataFrame.")
# Out:
# Contagem de tipos de contrato:
# contract
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: count, dtype: int64
#
# Contagem agrupada por contrato e churn:
#          contract churn  contagem
# 0  Month-to-month    No      2220
# 1  Month-to-month   Yes      1655
# 2        One year    No      1307
# 3        One year   Yes       166
# 4        Two year    No      1647
# 5        Two year   Yes        48

# %% [markdown]
# ✅ Este código cobre:
# .value_counts() para contagens simples
#
# .groupby() para agrupamento com múltiplas variáveis
#
# .pivot_table() para gráfico de barras empilhadas
#
# Visualização com matplotlib

# %%
# Tabela cruzada
tabela = pd.crosstab(df_merged['contract'], df_merged['churn'], margins=True)
print("Tabela cruzada: contrato x churn")
print(tabela)

# Percentuais por linha
tabela_percentual = pd.crosstab(df_merged['contract'], df_merged['churn'], normalize='index') * 100
print("\nPercentual por tipo de contrato:")
print(tabela_percentual.round(2))

# Gráfico de barras empilhadas com percentual
tabela_percentual.plot(kind='bar', stacked=True, figsize=(8,5), colormap='coolwarm')
plt.title('Churn por Tipo de Contrato (%)')
plt.ylabel('Percentual')
plt.xlabel('Tipo de Contrato')
plt.legend(title='Churn')
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# Tabela cruzada: contrato x churn
# churn             No   Yes   All
# contract
# Month-to-month  2220  1655  3875
# One year        1307   166  1473
# Two year        1647    48  1695
# All             5174  1869  7043
#
# Percentual por tipo de contrato:
# churn              No    Yes
# contract
# Month-to-month  57.29  42.71
# One year        88.73  11.27
# Two year        97.17   2.83

# %% [markdown]
# 🎯 Resultado
# A correlação revela relações quantitativas (ex: "quanto maior o tempo de contrato, menor a mensalidade?")
#
# A tabela cruzada mostra associação entre categorias (ex: "clientes com contrato anual têm menos churn?")

# %% [markdown]
# ## 📊 Exemplo: Relação entre contract (tipo de contrato) e churn (abandono do cliente)

# %%
import pandas as pd

# Tabela de contingência simples
contingencia = pd.crosstab(df_merged['contract'], df_merged['churn'])
print("Tabela de contingência (frequência absoluta):")
print(contingencia)

# Tabela de contingência percentual por linha
percentual = pd.crosstab(df_merged['contract'], df_merged['churn'], normalize='index') * 100
print("\nDistribuição percentual por tipo de contrato:")
print(percentual.round(2))
# Out:
# Tabela de contingência (frequência absoluta):
# churn             No   Yes
# contract
# Month-to-month  2220  1655
# One year        1307   166
# Two year        1647    48
#
# Distribuição percentual por tipo de contrato:
# churn              No    Yes
# contract
# Month-to-month  57.29  42.71
# One year        88.73  11.27
# Two year        97.17   2.83

# %% [markdown]
# ### 📈 Visualização da Tabela

# %%
import matplotlib.pyplot as plt

# Gráfico de barras empilhadas com percentuais
percentual.plot(kind='bar', stacked=True, colormap='coolwarm', figsize=(8,5))
plt.title('Distribuição de Churn por Tipo de Contrato (%)')
plt.xlabel('Tipo de Contrato')
plt.ylabel('Percentual (%)')
plt.legend(title='Churn')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 🔍 Interpretação
# Se as proporções de churn diferem muito entre os tipos de contrato (mensal, anual, etc.), existe uma associação entre essas variáveis.
#
# Uma proporção alta de churn no contrato mensal, por exemplo, sugere que esse tipo tem maior risco de abandono.

# %% [markdown]
# ✅ Objetivo
# Verificar se existe associação entre duas variáveis qualitativas, como:
#
# contract (mensal, anual, bienal)
#
# churn (sim/não)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import chi2_contingency

# %% [markdown]
# ###  Passo a passo com exemplo real:

# %%
# Criar tabela de contingência entre contract e churn
contingencia = pd.crosstab(df_merged['contract'], df_merged['churn'])

# Visualizar a tabela
print("Tabela de contingência:")
print(contingencia)

# Teste Qui-Quadrado
chi2, p, dof, expected = chi2_contingency(contingencia)

print("\nResultado do teste Qui-Quadrado:")
print(f"Estatística Qui² = {chi2:.2f}")
print(f"p-valor = {p:.4f}")
print(f"Graus de liberdade = {dof}")
# Out:
# Tabela de contingência:
# churn             No   Yes
# contract
# Month-to-month  2220  1655
# One year        1307   166
# Two year        1647    48
#
# Resultado do teste Qui-Quadrado:
# Estatística Qui² = 1184.60
# p-valor = 0.0000
# Graus de liberdade = 2

# %% [markdown]
# 🧠 Interpretação
# Se o p-valor < 0.05: existe associação significativa entre as variáveis.
#
# Se o p-valor ≥ 0.05: não há evidência estatística de associação.

# %% [markdown]
# ### 📊 Gráfico opcional para ilustrar

# %%
# Gráfico de barras empilhadas para visualizar a distribuição
contingencia_percent = pd.crosstab(df_merged['contract'], df_merged['churn'], normalize='index') * 100
contingencia_percent.plot(kind='bar', stacked=True, colormap='Set2', figsize=(8,5))
plt.title("Distribuição de Churn por Tipo de Contrato")
plt.ylabel("Percentual (%)")
plt.xlabel("Tipo de Contrato")
plt.legend(title="Churn")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Vamos implementar passo a passo a análise de associação entre churn e clientes com menos de 6 meses de contrato, transformando a variável quantitativa tenure (tempo de contrato) em uma variável categórica (tenure_<6_meses), e aplicando o teste Qui-Quadrado (Qsquare).

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# Criar nova variável qualitativa baseada em tenure
df_merged['tenure_<6_meses'] = df_merged['tenure'].apply(lambda x: 'yes' if x < 6 else 'no')

# Tabela de contingência entre churn e nova variável
tabela_contingencia = pd.crosstab(df_merged['tenure_<6_meses'], df_merged['churn'])

# Visualizar a tabela
print("Tabela de Contingência:\n", tabela_contingencia)

# Teste Qui-Quadrado
chi2, p, dof, expected = chi2_contingency(tabela_contingencia)

# Resultado
print("\nTeste Qui-Quadrado:")
print(f"Qui² = {chi2:.2f}")
print(f"p-valor = {p:.4f}")
print(f"Graus de liberdade = {dof}")
# Out:
# Tabela de Contingência:
#  churn              No   Yes
# tenure_<6_meses
# no               4547  1125
# yes               627   744
#
# Teste Qui-Quadrado:
# Qui² = 669.72
# p-valor = 0.0000
# Graus de liberdade = 1

# %% [markdown]
# 🧠 Interpretação
# Se p < 0.05: existe associação significativa entre churn e contratos com menos de 6 meses.
#
# Se p ≥ 0.05: não há evidência estatística de associação.

# %%
import matplotlib.pyplot as plt

# Percentual de churn por tempo de contrato (<6 meses)
tabela_pct = pd.crosstab(df_merged['tenure_<6_meses'], df_merged['churn'], normalize='index') * 100
tabela_pct.plot(kind='bar', stacked=True, colormap='Accent')
plt.title('Churn por Tempo de Contrato (<6 Meses)')
plt.ylabel('Percentual (%)')
plt.xlabel('Tempo de Contrato < 6 Meses')
plt.legend(title='Churn')
plt.tight_layout()
plt.show()

# %% [markdown]
# Vamos fazer uma análise comparativa da associação entre churn e outras variáveis qualitativas relevantes:
#
# 🧪 Variáveis a analisar:
# tenure_<6_meses (já transformada a partir de tenure)
#
# contract
#
# paymentmethod
#
# seniorcitizen
#
# Vamos aplicar o teste Qui-Quadrado em cada uma e comparar os p-valores.

# %%
import pandas as pd
from scipy.stats import chi2_contingency
import matplotlib.pyplot as plt

# Recriar a coluna de contratos menores que 6 meses
df_merged['tenure_<6_meses'] = df_merged['tenure'].apply(lambda x: 'yes' if x < 6 else 'no')

# Lista de variáveis categóricas para testar associação com churn
variaveis = ['tenure_<6_meses', 'contract', 'paymentmethod', 'seniorcitizen']

# Armazenar os resultados
resultados = []

for var in variaveis:
    # Criar tabela de contingência
    tabela = pd.crosstab(df_merged[var], df_merged['churn'])
    
    # Aplicar o teste Qui-Quadrado
    chi2, p, dof, expected = chi2_contingency(tabela)
    
    # Salvar resultado
    resultados.append({
        'variavel': var,
        'qui2': round(chi2, 2),
        'p_valor': round(p, 4),
        'graus_liberdade': dof
    })

# Converter para DataFrame
df_resultados = pd.DataFrame(resultados)
print(df_resultados)
# Out:
#           variavel     qui2  p_valor  graus_liberdade
# 0  tenure_<6_meses   669.72      0.0                1
# 1         contract  1184.60      0.0                2
# 2    paymentmethod   648.14      0.0                3
# 3    seniorcitizen   159.43      0.0                1

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Lista de variáveis categóricas para plotar
variaveis = ['tenure_<6_meses', 'contract', 'paymentmethod', 'seniorcitizen']

# Loop para gerar os gráficos empilhados
for var in variaveis:
    # Tabela de proporção normalizada (por linha)
    prop = pd.crosstab(df_merged[var], df_merged['churn'], normalize='index')
    
    # Gráfico de barras empilhadas
    prop.plot(kind='bar', stacked=True, figsize=(7,4), colormap='Set2')
    plt.title(f'Distribuição de Churn por: {var}')
    plt.ylabel('Proporção')
    plt.xlabel(var)
    plt.legend(title='Churn', loc='upper right')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# Para fechar a aula com um resumo prático, aqui está o código completo que você pode usar para calcular as correlações e visualizar a relação entre tenure e totalcharges com gráfico de dispersão:
#
# ✅ Correlação e gráfico entre tenure e totalcharges

# %%
# Garantir que totalcharges está no tipo float
df_merged['totalcharges'] = pd.to_numeric(df_merged['totalcharges'], errors='coerce')

# Filtrar apenas valores válidos (não nulos)
df_temp = df_merged[['tenure', 'totalcharges']].dropna()

# Correlações
from scipy.stats import pearsonr, spearmanr

pearson_corr, _ = pearsonr(df_temp['tenure'], df_temp['totalcharges'])
spearman_corr, _ = spearmanr(df_temp['tenure'], df_temp['totalcharges'])

print(f"Correlação de Pearson: {pearson_corr:.2f}")
print(f"Correlação de Spearman: {spearman_corr:.2f}")
# Out:
# Correlação de Pearson: 0.83
# Correlação de Spearman: 0.89

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import pearsonr, spearmanr

# Remover registros com valores nulos em totalcharges ou tenure
df_temp = df_merged[['tenure', 'totalcharges']].dropna()

# Correlação de Pearson (linear)
pearson_corr, _ = pearsonr(df_temp['tenure'], df_temp['totalcharges'])

# Correlação de Spearman (monótona)
spearman_corr, _ = spearmanr(df_temp['tenure'], df_temp['totalcharges'])

print(f"Correlação de Pearson: {pearson_corr:.2f}")
print(f"Correlação de Spearman: {spearman_corr:.2f}")

# Gráfico de dispersão
plt.figure(figsize=(8,5))
plt.scatter(df_temp['tenure'], df_temp['totalcharges'], alpha=0.5)
plt.title('Relação entre Tempo de Contrato (Tenure) e Total Pago (TotalCharges)')
plt.xlabel('Tempo de Contrato (meses)')
plt.ylabel('Total Pago (R$)')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Correlação de Pearson: 0.83
# Correlação de Spearman: 0.89

# %% [markdown]
# 📌 Interpretação:
# Pearson > 0.9 → forte correlação linear (quanto maior o tenure, maior o totalcharges);
#
# Spearman > 0.9 → relação monótona positiva (ordens crescem juntas);
#
# O gráfico de dispersão reforça essa intuição visualmente.

# %% [markdown]
# posso adaptar o código para validar as hipóteses desafiadoras com base em faixa etária ou tipo de contrato.

# %% [markdown]
# 🔍 Hipóteses:
# Clientes mais jovens têm maior taxa de churn.
#
# Clientes com contrato mensal tendem a cancelar mais do que clientes com contrato anual.
#
# ✅ Requisitos para validação:
# A coluna churn deve estar binarizada (ex: 'Yes' e 'No', ou 1 e 0)
#
# A coluna contract deve conter o tipo do contrato (ex: 'Month-to-month', 'One year', 'Two year')
#
# Teremos que criar a faixa etária a partir de alguma coluna como idade (mas seu dataset usa seniorcitizen como binária – podemos adaptar)
#
# As análises incluirão tabela de contingência, gráfico de barras e teste de qui-quadrado (chi²)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import chi2_contingency

# Garantir consistência
df_merged['churn'] = df_merged['churn'].str.lower()

# HIPÓTESE 1: Clientes mais jovens têm maior churn

# Criar faixas de idade com base em seniorcitizen (0 = jovem, 1 = idoso)
df_merged['faixa_etaria'] = df_merged['seniorcitizen'].map({0: 'Jovem', 1: 'Idoso'})

# Tabela de contingência
cont1 = pd.crosstab(df_merged['faixa_etaria'], df_merged['churn'])

# Gráfico
cont1.plot(kind='bar', stacked=True)
plt.title("Churn por Faixa Etária")
plt.xlabel("Faixa Etária")
plt.ylabel("Número de Clientes")
plt.legend(title="Churn")
plt.tight_layout()
plt.show()

# Teste Qui-Quadrado
chi2, p1, _, _ = chi2_contingency(cont1)
print(f"p-valor (faixa etária vs churn): {p1:.4f}")

# HIPÓTESE 2: Contrato mensal tem mais churn

# Tabela de contingência
cont2 = pd.crosstab(df_merged['contract'], df_merged['churn'])

# Gráfico
cont2.plot(kind='bar', stacked=True)
plt.title("Churn por Tipo de Contrato")
plt.xlabel("Tipo de Contrato")
plt.ylabel("Número de Clientes")
plt.legend(title="Churn")
plt.tight_layout()
plt.show()

# Teste Qui-Quadrado
chi2, p2, _, _ = chi2_contingency(cont2)
print(f"p-valor (tipo de contrato vs churn): {p2:.4f}")
# Out:
# p-valor (faixa etária vs churn): 0.0000
# p-valor (tipo de contrato vs churn): 0.0000

# %% [markdown]
# Perfeito. Esse gráfico confirma visualmente que a maior parte dos clientes que cancelam estão na faixa “Jovem”, o que dá suporte inicial à Hipótese 1.
#
# Agora, para concluir com evidência estatística, veja a saída do p-valor gerado com o teste qui-quadrado (chi²):
#
# ✅ Interpretação do p-valor:
# Se p < 0.05, há associação significativa entre faixa etária e churn.
#
# Se p ≥ 0.05, não podemos afirmar que existe associação.
#
# Você pode verificar isso no print(f"p-valor (faixa etária vs churn): {p1:.4f}").

# %% [markdown]
# Gerar o gráfico para a Hipótese 2 (tipo de contrato).

# %%
# Reimportar bibliotecas após reset
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import chi2_contingency

# Recarregar os dados
churn_contracts = pd.read_csv("churn_contracts.csv")
churn_customers = pd.read_csv("churn_customers.csv")
churn_services = pd.read_csv("churn_services.csv")

# Padronizar nomes de colunas
churn_contracts.columns = churn_contracts.columns.str.lower()
churn_customers.columns = churn_customers.columns.str.lower()
churn_services.columns = churn_services.columns.str.lower()

# Corrigir possíveis espaços em branco
churn_contracts.columns = churn_contracts.columns.str.strip()
churn_customers.columns = churn_customers.columns.str.strip()
churn_services.columns = churn_services.columns.str.strip()

# Corrigir tipo da coluna totalcharges
churn_contracts['totalcharges'] = pd.to_numeric(churn_contracts['totalcharges'], errors='coerce')

# Unificar os dados
df_merged = churn_customers.merge(churn_contracts, on="customerid", how="left")
df_merged = df_merged.merge(churn_services, on="customerid", how="left")

# Criar nova variável com tipo de contrato simplificado
df_merged['tipo_contrato_simplificado'] = df_merged['contract'].map({
    'Month-to-month': 'Mensal',
    'One year': 'Anual',
    'Two year': 'Bienal'
})

# Tabela de contingência: churn vs tipo de contrato
tabela_contrato = pd.crosstab(df_merged['tipo_contrato_simplificado'], df_merged['churn'])

# Gráfico de barras empilhadas
tabela_contrato.plot(kind='bar', stacked=True)
plt.title('Churn por Tipo de Contrato')
plt.xlabel('Tipo de Contrato')
plt.ylabel('Número de Clientes')
plt.xticks(rotation=0)
plt.legend(title='Churn')
plt.tight_layout()
plt.show()

# Teste qui-quadrado
_, p_valor_contrato, _, _ = chi2_contingency(tabela_contrato)

p_valor_contrato
# Out:
# np.float64(5.863038300673391e-258)

# %% [markdown]
# A análise mostrou que existe uma forte associação estatística entre o tipo de contrato e o churn dos clientes.
#
# ✅ Valor-p do teste Qui-Quadrado: 5.86e-258 — ou seja, praticamente zero.
#
# Isso indica que é altamente improvável que a distribuição de churn entre os diferentes tipos de contrato seja aleatória. O gráfico mostra que:
#
# Contratos mensais têm muito mais churn.
#
# Contratos anuais e bienais têm uma taxa de churn muito menor.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Criar a tabela de contingência novamente para o gráfico
tabela_contingencia = pd.crosstab(df_merged['contract'], df_merged['churn'])

# Plotando gráfico de barras empilhadas para tipo de contrato vs churn
tabela_contingencia.plot(kind='bar', stacked=True, colormap='Set1', figsize=(8, 5))
plt.title("Churn por Tipo de Contrato")
plt.xlabel("Tipo de Contrato")
plt.ylabel("Número de Clientes")
plt.xticks(rotation=0)
plt.legend(title="Churn")
plt.tight_layout()

# Salvar imagem para incluir no markdown
grafico_path = "churn_por_tipo_de_contrato.png"
plt.savefig(grafico_path)

grafico_path
# Out:
# 'churn_por_tipo_de_contrato.png'

# %% [markdown]
# ## Identificar outliers com base no desvio interquartil (IQR) e aplicar estratégias de tratamento.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Exemplo com a variável 'totalcharges'
coluna = 'totalcharges'

# 1. Calcular quartis e IQR
Q1 = df_merged[coluna].quantile(0.25)
Q3 = df_merged[coluna].quantile(0.75)
IQR = Q3 - Q1

# 2. Definir limites inferior e superior
limite_inferior = Q1 - 1.5 * IQR
limite_superior = Q3 + 1.5 * IQR

# 3. Identificar outliers
outliers = df_merged[(df_merged[coluna] < limite_inferior) | (df_merged[coluna] > limite_superior)]

print(f"Quantidade de outliers detectados: {len(outliers)}")

# 4. Visualização com boxplot
plt.figure(figsize=(8, 4))
plt.boxplot(df_merged[coluna].dropna())
plt.title(f'Distribuição de {coluna}')
plt.ylabel(coluna)
plt.grid(True)
plt.show()
# Out:
# Quantidade de outliers detectados: 0

# %% [markdown]
# 💡 O que fazer com os outliers?
# Você pode escolher uma das abordagens abaixo, conforme o seu caso:

# %% [markdown]
# 1. Remover os outliers

# %%
df_sem_outliers = df_merged[(df_merged[coluna] >= limite_inferior) & (df_merged[coluna] <= limite_superior)]

# %% [markdown]
# 2. Substituir por limite máximo/mínimo

# %%
df_tratado = df_merged.copy()
df_tratado.loc[df_tratado[coluna] > limite_superior, coluna] = limite_superior
df_tratado.loc[df_tratado[coluna] < limite_inferior, coluna] = limite_inferior

# %% [markdown]
#  Agrupar os outliers é uma alternativa útil quando você não quer descartá-los nem alterar seus valores, mas deseja analisá-los separadamente ou marcar sua presença para modelagem.
#
# Aqui está como você pode identificá-los e marcá-los como uma nova categoria, criando uma coluna is_outlier:

# %% [markdown]
# ✅ Código para marcar/agrupar outliers

# %%
import pandas as pd

# Definindo a variável a ser analisada
coluna = 'totalcharges'

# 1. Calcular quartis e IQR
Q1 = df_merged[coluna].quantile(0.25)
Q3 = df_merged[coluna].quantile(0.75)
IQR = Q3 - Q1

# 2. Limites inferior e superior
limite_inferior = Q1 - 1.5 * IQR
limite_superior = Q3 + 1.5 * IQR

# 3. Criar coluna binária indicando outlier (True/False)
df_merged['is_outlier_totalcharges'] = ~df_merged[coluna].between(limite_inferior, limite_superior)

# Verificar distribuição
print(df_merged['is_outlier_totalcharges'].value_counts())
# Out:
# is_outlier_totalcharges
# False    7032
# True       11
# Name: count, dtype: int64

# %% [markdown]
# 📊 Exemplo de agrupamento
# Se quiser comparar churn entre outliers e não-outliers, use:

# %%
# Agrupar por presença de outlier e calcular proporção de churn
agrupado = df_merged.groupby('is_outlier_totalcharges')['churn'].value_counts(normalize=True).unstack()
print(agrupado)
# Out:
# churn                          No       Yes
# is_outlier_totalcharges
# False                    0.734215  0.265785
# True                     1.000000       NaN

# %% [markdown]
# 📈 Visualização opcional

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
sns.boxplot(x='is_outlier_totalcharges', y='totalcharges', data=df_merged)
plt.title('Distribuição de TotalCharges por presença de Outlier')
plt.xlabel('É outlier?')
plt.ylabel('TotalCharges')
plt.show()

# %% [markdown]
# aplicar esse agrupamento para outras variáveis como monthlycharges ou tenure, basta repetir a lógica mudando o nome da coluna. Posso montar uma função reutilizável

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

def marcar_outliers(df, coluna, plotar=False):
    """
    Identifica outliers com base no método IQR e marca no DataFrame.

    Parâmetros:
        df (DataFrame): DataFrame de entrada.
        coluna (str): Nome da coluna numérica a ser analisada.
        plotar (bool): Se True, exibe um boxplot comparando outliers.

    Retorno:
        DataFrame com nova coluna 'is_outlier_<coluna>'
    """
    # Calcular Q1, Q3 e IQR
    Q1 = df[coluna].quantile(0.25)
    Q3 = df[coluna].quantile(0.75)
    IQR = Q3 - Q1

    # Limites inferior e superior
    lim_inf = Q1 - 1.5 * IQR
    lim_sup = Q3 + 1.5 * IQR

    # Nome da nova coluna
    nome_col = f'is_outlier_{coluna.lower()}'

    # Marcar outliers
    df[nome_col] = ~df[coluna].between(lim_inf, lim_sup)

    # Exibir boxplot se solicitado
    if plotar:
        plt.figure(figsize=(6,4))
        sns.boxplot(x=nome_col, y=coluna, data=df)
        plt.title(f'Distribuição de {coluna} por presença de Outlier')
        plt.xlabel('É outlier?')
        plt.ylabel(coluna)
        plt.show()
    
    return df

# %%
# Para totalcharges com visualização
df_merged = marcar_outliers(df_merged, 'totalcharges', plotar=True)

# Para monthlycharges sem gráfico
df_merged = marcar_outliers(df_merged, 'monthlycharges')

# %% [markdown]
# Filtra apenas clientes com contrato mensal;
#
# Verifica visualmente a distribuição (histograma);
#
# Aplica boxplot simples e boxplot agrupado por tipo de contrato;
#
# Detecta outliers com base no IQR por grupo.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Filtrar apenas contratos mensais
df_mensal = df_merged[df_merged['contract'] == 'Month-to-month']

# Histograma para verificar distribuição
plt.figure(figsize=(6,4))
sns.histplot(df_mensal['totalcharges'], bins=30, kde=True)
plt.title('Distribuição de TotalCharges - Contratos Mensais')
plt.xlabel('Total Charges')
plt.ylabel('Frequência')
plt.show()

# Boxplot simples para TotalCharges
plt.figure(figsize=(5,4))
sns.boxplot(y='totalcharges', data=df_mensal)
plt.title('Boxplot de TotalCharges - Contratos Mensais')
plt.show()

# Boxplot agrupado por tipo de contrato
plt.figure(figsize=(8,5))
sns.boxplot(x='contract', y='totalcharges', data=df_merged)
plt.title('TotalCharges por Tipo de Contrato')
plt.xlabel('Tipo de Contrato')
plt.ylabel('Total Charges')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# 💡 Detecção de outliers por grupo (por tipo de contrato)
# Se quiser marcar os outliers separadamente dentro de cada grupo, aqui vai uma função adaptada:

# %%
def detectar_outliers_por_grupo(df, grupo, coluna):
    """
    Adiciona uma coluna indicando se é outlier com base no IQR, por grupo.
    """
    nome_col = f'outlier_{coluna.lower()}'
    
    df[nome_col] = False
    
    for grupo_valor, grupo_df in df.groupby(grupo):
        Q1 = grupo_df[coluna].quantile(0.25)
        Q3 = grupo_df[coluna].quantile(0.75)
        IQR = Q3 - Q1
        lim_inf = Q1 - 1.5 * IQR
        lim_sup = Q3 + 1.5 * IQR
        
        idx_outliers = grupo_df[
            (grupo_df[coluna] < lim_inf) | (grupo_df[coluna] > lim_sup)
        ].index
        
        df.loc[idx_outliers, nome_col] = True

    return df

# %%
df_merged = detectar_outliers_por_grupo(df_merged, 'contract', 'totalcharges')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Carregar os dados unidos (df_merged já foi definido anteriormente)
# Para fins deste exemplo, simularemos um DataFrame similar com base nas colunas esperadas.

# Simulação mínima caso df_merged não exista (remover em uso real)
# df_merged = pd.read_csv('df_merged.csv') # Em uso real, usar isso.

# Filtrar apenas contratos mensais
df_mensal = df_merged[df_merged['contract'] == 'Month-to-month']

# Histograma para verificar distribuição
plt.figure(figsize=(6,4))
sns.histplot(df_mensal['totalcharges'], bins=30, kde=True)
plt.title('Distribuição de TotalCharges - Contratos Mensais')
plt.xlabel('Total Charges')
plt.ylabel('Frequência')
plt.tight_layout()
plt.show()

# Boxplot simples para TotalCharges
plt.figure(figsize=(5,4))
sns.boxplot(y='totalcharges', data=df_mensal)
plt.title('Boxplot de TotalCharges - Contratos Mensais')
plt.tight_layout()
plt.show()

# Boxplot agrupado por tipo de contrato
plt.figure(figsize=(8,5))
sns.boxplot(x='contract', y='totalcharges', data=df_merged)
plt.title('TotalCharges por Tipo de Contrato')
plt.xlabel('Tipo de Contrato')
plt.ylabel('Total Charges')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Acima estão os três gráficos gerados:
#
# Histograma da variável totalcharges para clientes com contrato mensal — mostra uma distribuição assimétrica à direita.
#
# Boxplot simples para totalcharges desses mesmos clientes — não indica outliers evidentes.
#
# Boxplot por tipo de contrato — revela que há outliers visíveis principalmente nos contratos de um ano.

# %% [markdown]
# Passo a passo do método IQR:
# Calcular o Q1 (1º quartil) e Q3 (3º quartil).
#
# Calcular o IQR = Q3 - Q1.
#
# Definir os limites:
#
# Limite inferior = Q1 - 1.5 × IQR
#
# Limite superior = Q3 + 1.5 × IQR
#
# Os valores fora desses limites são considerados outliers.

# %%
import pandas as pd

# Criar cópia do DataFrame para não alterar o original
df_outliers = df_merged[['contract', 'totalcharges']].copy()

# Garantir que 'totalcharges' esteja no formato numérico
df_outliers['totalcharges'] = pd.to_numeric(df_outliers['totalcharges'], errors='coerce')

# Remover valores nulos
df_outliers = df_outliers.dropna()

# Lista para armazenar outliers
outliers_detectados = []

# Detectar outliers por tipo de contrato
for contrato in df_outliers['contract'].unique():
    grupo = df_outliers[df_outliers['contract'] == contrato]
    
    Q1 = grupo['totalcharges'].quantile(0.25)
    Q3 = grupo['totalcharges'].quantile(0.75)
    IQR = Q3 - Q1

    limite_inferior = Q1 - 1.5 * IQR
    limite_superior = Q3 + 1.5 * IQR

    outliers = grupo[(grupo['totalcharges'] < limite_inferior) | (grupo['totalcharges'] > limite_superior)]
    outliers_detectados.append(outliers)

# Concatenar todos os outliers detectados em um único DataFrame
df_outliers_final = pd.concat(outliers_detectados)

# Exibir os 10 primeiros outliers
print(df_outliers_final.head(10))

# Ou, se quiser salvar em um arquivo CSV para abrir no Excel
df_outliers_final.to_csv("outliers_totalcharges_por_contrato.csv", index=False)
# Out:
#            contract  totalcharges
# 13   Month-to-month       5036.30
# 61   Month-to-month       5450.70
# 93   Month-to-month       7107.00
# 110  Month-to-month       5238.90
# 197  Month-to-month       6519.75
# 243  Month-to-month       6126.15
# 276  Month-to-month       5624.85
# 325  Month-to-month       5138.10
# 339  Month-to-month       6603.00
# 402  Month-to-month       7007.60

# %%
import matplotlib.pyplot as plt

# Boxplot agrupado por tipo de contrato para visualizar outliers
plt.figure(figsize=(8, 5))
df_mensal[['contract', 'totalcharges']].boxplot(by='contract', grid=False)
plt.title('Boxplot de TotalCharges por Tipo de Contrato')
plt.suptitle('')
plt.ylabel('Total Charges')
plt.xlabel('Tipo de Contrato')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# Mostrar os 10 primeiros outliers detectados
print(df_outliers_final.head(10))

# Exportar para CSV
df_outliers_final.to_csv("outliers_totalcharges_por_contrato.csv", index=False)
# Out:
#            contract  totalcharges
# 13   Month-to-month       5036.30
# 61   Month-to-month       5450.70
# 93   Month-to-month       7107.00
# 110  Month-to-month       5238.90
# 197  Month-to-month       6519.75
# 243  Month-to-month       6126.15
# 276  Month-to-month       5624.85
# 325  Month-to-month       5138.10
# 339  Month-to-month       6603.00
# 402  Month-to-month       7007.60

# %% [markdown]
# ✅ O que esse código faz:
# Calcula Q1 (25%) e Q3 (75%) da coluna totalcharges
#
# Calcula o IQR
#
# Define os limites inferior e superior usando o fator 1.5 * IQR
#
# Filtra os dados fora desses limites
#
# Mostra e salva os outliers detectados
#
# Se quiser aplicar isso a outras colunas automaticamente (por exemplo, monthlycharges, tenure)

# %%
import pandas as pd

# Supondo que df_merged seja o DataFrame consolidado
# Vamos trabalhar apenas com a variável totalcharges e ignorar valores nulos
df = df_merged[['totalcharges']].dropna()

# Calcular os quartis
Q1 = df['totalcharges'].quantile(0.25)
Q3 = df['totalcharges'].quantile(0.75)
IQR = Q3 - Q1  # Intervalo interquartil

# Limites inferior e superior
limite_inferior = Q1 - 1.5 * IQR
limite_superior = Q3 + 1.5 * IQR

# Identificar os outliers
outliers = df[(df['totalcharges'] < limite_inferior) | (df['totalcharges'] > limite_superior)]

# Exibir os outliers
print("Quantidade de outliers:", len(outliers))
print(outliers.head())

# Salvar os outliers em um CSV
outliers.to_csv("outliers_tukey_totalcharges.csv", index=False)
# Out:
# Quantidade de outliers: 0
# Empty DataFrame
# Columns: [totalcharges]
# Index: []

# %%
import pandas as pd

# Suponha que df_merged já esteja carregado
# Lista de colunas numéricas que deseja analisar
colunas_numericas = ['totalcharges', 'monthlycharges', 'tenure']

# Dicionário para armazenar os outliers por coluna
outliers_dict = {}

for coluna in colunas_numericas:
    # Elimina nulos temporariamente
    df_coluna = df_merged[[coluna]].dropna()

    # Calcula os quartis e o IQR
    Q1 = df_coluna[coluna].quantile(0.25)
    Q3 = df_coluna[coluna].quantile(0.75)
    IQR = Q3 - Q1

    # Limites inferior e superior
    limite_inferior = Q1 - 1.5 * IQR
    limite_superior = Q3 + 1.5 * IQR

    # Seleciona os outliers
    outliers = df_merged[(df_merged[coluna] < limite_inferior) | (df_merged[coluna] > limite_superior)]

    # Armazena
    outliers_dict[coluna] = outliers

    # Exporta para CSV
    outliers.to_csv(f'outliers_{coluna}_tukey.csv', index=False)

    print(f"[{coluna}] -> {len(outliers)} outliers salvos em 'outliers_{coluna}_tukey.csv'.")

# Acessar os DataFrames:
# Exemplo: outliers_dict['monthlycharges']
# Out:
# [totalcharges] -> 0 outliers salvos em 'outliers_totalcharges_tukey.csv'.
# [monthlycharges] -> 0 outliers salvos em 'outliers_monthlycharges_tukey.csv'.
# [tenure] -> 0 outliers salvos em 'outliers_tenure_tukey.csv'.

# %% [markdown]
# Para complementar essa aula, segue o código completo para detectar outliers com Z-Score, ideal para distribuições aproximadamente normais

# %%
import pandas as pd
import numpy as np
from scipy.stats import zscore

# Suponha que df_merged esteja carregado e com colunas numéricas convertidas corretamente
colunas_numericas = ['totalcharges', 'monthlycharges', 'tenure']

# Aplica o Z-Score nas colunas selecionadas (ignora nulos)
z_scores = df_merged[colunas_numericas].apply(zscore)

# Converte para valores absolutos
z_abs = np.abs(z_scores)

# Define limite para ser considerado outlier
limite = 3

# Detecta linhas com pelo menos um z-score acima do limite
outliers_zscore = df_merged[(z_abs > limite).any(axis=1)]

# Resultado
print(f'Total de outliers detectados com Z-Score: {len(outliers_zscore)}')

# Exporta para CSV
outliers_zscore.to_csv('outliers_zscore.csv', index=False)
# Out:
# Total de outliers detectados com Z-Score: 0

# %% [markdown]
# ## EDA AUTOMATIZADA -

# %% [markdown]
# ### SWEETVIZ

# %%
import sweetviz as sv
import pandas as pd

# Supondo que df_merged já esteja carregado e preparado
relatorio = sv.analyze(df_merged)
relatorio.show_html('relatorio_eda.html')
# Out:
# Feature: tenure                              |██▎       | [ 23%]   02:47 -> (09:18 left)
# Feature: tenure                              |██▎       | [ 23%]   01:35 -> (05:17 left)
# Feature: tenure                              |██▎       | [ 23%]   00:00 -> (00:02 left)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[112], line 5
#       2 import pandas as pd
#       4 # Supondo que df_merged já esteja carregado e preparado
# ----> 5 relatorio = sv.analyze(df_merged)
#       6 relatorio.show_html('relatorio_eda.html')
#
# File ~/.local/share/virtualenvs/estatistica_devs-MKbpRP2F/lib/python3.11/site-packages/sweetviz/sv_public.py:12, in analyze(source, target_feat, feat_cfg, pairwise_analysis)
#       8 def analyze(source: Union[pd.DataFrame, Tuple[pd.DataFrame, str]],
#       9             target_feat: str = None,
#      10             feat_cfg: FeatureConfig = None,
# ...

# %% [markdown]
# 📊 O que o relatório inclui:
# Distribuição de variáveis (categóricas e numéricas)
#
# Comparações entre classes (como churn vs não churn)
#
# Correlações
#
# Dados ausentes
#
# Outliers
#
# Análise de targets (se você passar um target_feat)

# %% [markdown]
# ✅ Dica extra: comparação entre dois conjuntos
# Se quiser comparar, por exemplo, clientes que deram churn vs os que não deram, faça:

# %%
df_churn = df_merged[df_merged['churn'] == 'Yes']
df_no_churn = df_merged[df_merged['churn'] == 'No']

comparacao = sv.compare([df_churn, "Churn"], [df_no_churn, "No Churn"])
comparacao.show_html("comparativo_churn.html")
# Out:
# Feature: tenure                              |██▎       | [ 23%]   00:00 -> (00:01 left)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[110], line 4
#       1 df_churn = df_merged[df_merged['churn'] == 'Yes']
#       2 df_no_churn = df_merged[df_merged['churn'] == 'No']
# ----> 4 comparacao = sv.compare([df_churn, "Churn"], [df_no_churn, "No Churn"])
#       5 comparacao.show_html("comparativo_churn.html")
#
# File ~/.local/share/virtualenvs/estatistica_devs-MKbpRP2F/lib/python3.11/site-packages/sweetviz/sv_public.py:22, in compare(source, compare, target_feat, feat_cfg, pairwise_analysis)
#      17 def compare(source: Union[pd.DataFrame, Tuple[pd.DataFrame, str]],
#      18             compare: Union[pd.DataFrame, Tuple[pd.DataFrame, str]],
#      19             target_feat: str = None,
#      20             feat_cfg: FeatureConfig = None,
# ...
