# %% [markdown]
# # 🧪 Aula Prática: Ambiente, Visualização e Exploração Inicial de Dados

# %% [markdown]
# ## 🗂️ 1. Configurando o ambiente de trabalho
# Antes de iniciar, crie uma pasta chamada `analise_de_dados` no seu sistema e ative um ambiente virtual Python (recomenda-se usar `venv` ou `pipenv`).

# %% [markdown]
# ### Instale as bibliotecas necessárias:

# %%
pip install pandas matplotlib seaborn

# %% [markdown]
# ## 📦 2. Importando bibliotecas

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## 📄 3. Gerando um dataset fictício
# > Como os dados são aleatórios e não controlados, simularemos um conjunto com variáveis comuns em análises preditivas.

# %%
np.random.seed(42)

# %%
df = pd.DataFrame({
    "idade": np.random.randint(20, 70, 100),
    "peso": np.random.normal(70, 15, 100),
    "altura": np.random.normal(1.65, 0.1, 100),
    "pressao_sistolica": np.random.randint(100, 160, 100),
    "diabetico": np.random.choice([0, 1], size=100)
})

# %%
df.head()
# Out:
#    idade       peso    altura  pressao_sistolica  diabetico
# 0     58  41.864848  1.547229                111          1
# 1     48  49.498268  1.724124                152          0
# 2     34  79.544577  1.478947                100          1
# 3     62  56.399190  1.661898                157          1
# 4     27  77.140639  1.750049                157          0

# %% [markdown]
# ## 📊 4. Análise inicial dos dados

# %%
df.describe()
# Out:
#             idade        peso      altura  pressao_sistolica  diabetico
# count  100.000000  100.000000  100.000000         100.000000     100.00
# mean    44.070000   70.584245    1.643894         129.470000       0.45
# std     14.447575   15.273857    0.101105          17.702625       0.50
# min     20.000000   40.901332    1.418193         100.000000       0.00
# 25%     33.000000   58.368135    1.576684         115.000000       0.00
# 50%     43.000000   69.051088    1.637854         130.500000       0.00
# 75%     58.000000   81.242649    1.709827         145.250000       1.00
# max     69.000000  114.154951    1.956110         159.000000       1.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   idade              100 non-null    int64
#  1   peso               100 non-null    float64
#  2   altura             100 non-null    float64
#  3   pressao_sistolica  100 non-null    int64
#  4   diabetico          100 non-null    int64
# dtypes: float64(2), int64(3)
# memory usage: 4.0 KB

# %% [markdown]
# ## 📈 5. Visualização com Seaborn

# %% [markdown]
# ### Distribuição das variáveis

# %%
sns.histplot(df["idade"], kde=True)
plt.title("Distribuição de Idade")
plt.show()
sns.histplot(df["peso"], kde=True)
plt.title("Distribuição de Peso")
plt.show()

# %% [markdown]
# ### Relação entre variáveis

# %%
sns.scatterplot(x="idade", y="pressao_sistolica", hue="diabetico", data=df)
plt.title("Idade vs Pressão Sistólica (Colorido por Diabetes)")
plt.show()
sns.pairplot(df, hue="diabetico")

# %% [markdown]
# ## 🧮 6. Correlação

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Matriz de Correlação")
plt.show()

# %% [markdown]
# ## ✅ Conclusão

# %% [markdown]
# Mesmo com dados aleatórios, conseguimos:
# - Visualizar distribuições e relações
# - Aplicar técnicas gráficas com `seaborn` e `matplotlib`
# - Preparar terreno para feature engineering e modelagem futura

# %% [markdown]
# Esse processo é essencial para qualquer projeto de ciência de dados ou machine learning.
