# %% [markdown]
# # 🧨 A Maldição da Dimensionalidade
#
# ## ❗ O que é
#
# A **maldição da dimensionalidade** ocorre quando lidamos com dados que possuem **muitas variáveis (features)**. À medida que a dimensionalidade aumenta:
#
# - Os dados se tornam **esparsos**
# - A **distância entre os pontos** perde significado
# - Os algoritmos de ML têm **dificuldade para generalizar**
# - É necessário muito mais dados para manter a performance
#
# ---
#
# ## 📉 Impactos
#
# - Modelos overfitam mais fácil
# - Métricas de distância (como em KNN, clustering) ficam distorcidas
# - O tempo de processamento aumenta
# - A acurácia dos modelos tende a cair
#
# ---
#
# ## 🛠️ Técnicas para Lidar com Alta Dimensionalidade
#
# ### 1. ✂️ Seleção de Features (Feature Selection)
# Seleciona apenas as variáveis mais relevantes para a predição.
#
# **Métodos comuns:**
# - `SelectKBest` com `chi2` ou `f_classif`
# - `Recursive Feature Elimination (RFE)`
# - Importância de features via `RandomForest`
#
# ### 2. 🧮 Redução de Dimensionalidade
# Cria novas variáveis combinando as existentes de forma mais compacta.
#
# **Técnicas populares:**
# - **PCA (Principal Component Analysis)**
# - **t-SNE** (para visualização)
# - **UMAP** (não-linear)
#
# ---
#
# ## 📈 Visualização com PCA
#
# ```python
# from sklearn.decomposition import PCA
# import matplotlib.pyplot as plt
# from sklearn.datasets import load_iris
#
# iris = load_iris()
# X = iris.data
# y = iris.target
#
# pca = PCA(n_components=2)
# X_pca = pca.fit_transform(X)
#
# plt.figure(figsize=(6, 4))
# plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y)
# plt.title("PCA - Redução de Dimensionalidade")
# plt.xlabel("PC1")
# plt.ylabel("PC2")
# plt.show()

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

iris = load_iris()
X = iris.data
y = iris.target

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

plt.figure(figsize=(6, 4))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y)
plt.title("PCA - Redução de Dimensionalidade")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()
