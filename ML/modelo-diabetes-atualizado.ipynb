# %% [markdown]
# # 🧪 Análise Inicial do Conjunto de Dados Médicos - Modelo de Diabetes

# %% [markdown]
# ## 📘 Introdução
# Neste notebook, faremos a análise exploratória de um conjunto de dados médicos contendo informações como:
# - ID do paciente
# - Gênero
# - Idade
# - Peso
# - Altura
# - Resultado do exame de diabetes (numérico)

# %% [markdown]
# Nosso objetivo é preparar os dados para modelagem preditiva (regressão).

# %% [markdown]
# ## 📦 Etapa 1: Importação das bibliotecas

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 📂 Etapa 2: Carregando os dados

# %%
# O arquivo deve estar na mesma pasta do notebook
df = pd.read_csv("exame_diabes.csv")
df.head(10)
# Out:
#    id_paciente genero  idade  peso  altura  resultado
# 0            1      M     46    83     165         98
# 1            2      F     23    83     164         82
# 2            3      M     39    71     154         93
# 3            4      F     26   103     165         95
# 4            5      M     27    55     176        100
# 5            6      M     64    93     190        117
# 6            7      F     21    70     182         90
# 7            8      F     60   101     179         84
# 8            9      F     63    83     189         92
# 9           10      F     65    78     175        121

# %% [markdown]
# ## ℹ️ Etapa 3: Estrutura dos dados

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id_paciente  100 non-null    int64
#  1   genero       100 non-null    object
#  2   idade        100 non-null    int64
#  3   peso         100 non-null    int64
#  4   altura       100 non-null    int64
#  5   resultado    100 non-null    int64
# dtypes: int64(5), object(1)
# memory usage: 4.8+ KB

# %%
df.describe()
# Out:
#        id_paciente       idade       peso      altura  resultado
# count   100.000000  100.000000  100.00000  100.000000  100.00000
# mean     50.500000   46.370000   87.89000  173.230000  106.32000
# std      29.011492   15.912421   20.13936   13.088552   13.87526
# min       1.000000   20.000000   55.00000  150.000000   80.00000
# 25%      25.750000   31.750000   71.00000  162.000000   95.00000
# 50%      50.500000   45.000000   88.00000  175.000000  107.50000
# 75%      75.250000   63.000000  105.25000  184.250000  117.25000
# max     100.000000   70.000000  120.00000  195.000000  130.00000

# %% [markdown]
# ## 📊 Etapa 4: Distribuição de variáveis

# %%
sns.histplot(df["idade"], kde=True)
plt.title("Distribuição de Idade")
plt.show()
sns.histplot(df["peso"], kde=True)
plt.title("Distribuição de Peso")
plt.show()

# %%
sns.histplot(df["altura"], kde=True)
plt.title("Distribuição de Altura")
plt.show()

# %%
sns.histplot(df["resultado"], kde=True)
plt.title("Distribuição dos Resultados de Exame")
plt.show()

# %% [markdown]
# ## 🔍 Etapa 5: Relação entre variáveis

# %%
sns.scatterplot(x="idade", y="resultado", hue="genero", data=df)
plt.title("Idade vs Resultado de Exame")
plt.show()
sns.scatterplot(x="peso", y="resultado", hue="genero", data=df)
plt.title("Peso vs Resultado de Exame")
plt.show()

# %% [markdown]
# ## 🧮 Etapa 6: Correlação

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="viridis", fmt=".2f")
plt.title("Matriz de Correlação entre Variáveis")
plt.show()

# %% [markdown]
# ## ✅ Conclusão

# %% [markdown]
# O conjunto está pronto para:
# - Engenharia de features (ex: criar IMC)
# - Modelagem com regressão (Linear, Árvore, etc.)
# - Avaliação com métricas contínuas
