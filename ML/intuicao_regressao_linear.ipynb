# %% [markdown]
# # 📈 Intuição sobre Regressão Linear com Seaborn

# %% [markdown]
# ## 🎯 Objetivo
# Entender de forma visual como funciona a regressão linear utilizando `sns.regplot`.

# %% [markdown]
# ## 📦 Etapa 1: Importar bibliotecas

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## 🧪 Etapa 2: Criar dataset fictício (tempo de casa vs salário)

# %%
df = pd.DataFrame({
    "tempo_casa": [1, 2, 3, 4, 5, 6, 7, 8],
    "salario": [2500, 2700, 3000, 3300, 3500, 3700, 4000, 4200]
})
df
# Out:
#    tempo_casa  salario
# 0           1     2500
# 1           2     2700
# 2           3     3000
# 3           4     3300
# 4           5     3500
# 5           6     3700
# 6           7     4000
# 7           8     4200

# %% [markdown]
# ## 📉 Etapa 3: Visualizar regressão linear

# %%
sns.regplot(x="tempo_casa", y="salario", data=df)
plt.title("Regressão Linear - Tempo de Casa vs Salário")
plt.xlabel("Tempo de Casa (anos)")
plt.ylabel("Salário (R$)")
plt.show()

# %% [markdown]
# ## 📚 Etapa 4: Intuição

# %% [markdown]
# A linha de regressão é uma estimativa da relação entre as duas variáveis:

# %%
- Quanto maior o tempo de casa, maior tende a ser o salário
- A reta foi ajustada minimizando a distância dos pontos reais até a linha (erro)

# %% [markdown]
# ## ✅ Conclusão

# %% [markdown]
# - `sns.regplot()` mostra a relação entre variáveis e a linha de melhor ajuste
# - Essa abordagem é fundamental para prever valores com base em tendências
# - A regressão linear é a base para diversos modelos preditivos
